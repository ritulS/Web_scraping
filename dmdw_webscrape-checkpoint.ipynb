# %%
import pandas as pd
# !pip3 install webdriver_manager
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
# Out:
# WARNING: You are using pip version 20.3.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\ritul\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: webdriver_manager in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (3.3.0)
# Requirement already satisfied: configparser in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (from webdriver_manager) (5.0.2)
# Requirement already satisfied: crayons in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (from webdriver_manager) (0.4.0)
# Requirement already satisfied: requests in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (from webdriver_manager) (2.25.1)
# Requirement already satisfied: colorama in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (from crayons->webdriver_manager) (0.4.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (from requests->webdriver_manager) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (from requests->webdriver_manager) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (from requests->webdriver_manager) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages (from requests->webdriver_manager) (4.0.0)

# %%
driver = webdriver.Chrome(executable_path = "C:\Program Files (x86)\chromedriver.exe")

# %%
driver.get("https://www.booking.com/searchresults.html?label=gen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4AonA0YMGwAIB0gIkYjEzZTcwMDAtYzc0MS00OWY2LTlhMmUtNWJlNTM5ZWI3ZGY42AIF4AIB&sid=5c9d81d37133b7e9abf7fe2ebb7a4196&aid=304142&sb=1&sb_lp=1&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4AonA0YMGwAIB0gIkYjEzZTcwMDAtYzc0MS00OWY2LTlhMmUtNWJlNTM5ZWI3ZGY42AIF4AIB%3Bsid%3D5c9d81d37133b7e9abf7fe2ebb7a4196%3Bsb_price_type%3Dtotal%26%3B&ss=Singapore%2C%20Singapore&is_ski_area=0&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1&ss_raw=singapore&ac_position=0&ac_langcode=en&ac_click_type=b&dest_id=-73635&dest_type=city&iata=SIN&place_id_lat=1.29045&place_id_lon=103.85204&search_pageview_id=03366944fc9d0098&search_selected=true&order=distance_from_search")

# %%
hotel_name = driver.find_elements_by_class_name('sr-hotel__title')

# %%
def search_country(driver, search_argument):
    search_country = driver.find_element_by_id('ss')
    search_country.send_keys(search_argument)
    # We look for the search button and click it
    driver.find_element_by_class_name('sb-searchbox__button')\
        .click()
    wait = WebDriverWait(driver, timeout=10).until(
        EC.presence_of_all_elements_located(
            (By.CLASS_NAME, 'sr-hotel__title')))

# %%
def scrape_hotel_url(driver, n_results):
    '''Returns the data from n_results amount of results.'''
 
    accommodations_urls = list()
    accommodations_data = list()
    
    # Get the accommodations links
    for accomodation_title in driver.find_elements_by_class_name('sr-hotel__title'):
        accommodations_urls.append(accomodation_title.find_element_by_class_name(
            'hotel_name_link').get_attribute('href'))
 
    Iterate over a defined range and scrape the links
    for url in range(0, n_results):
        if url == n_results:
            break
        url_data = scrape_accommodation_data(driver, accommodations_urls[url])
        accommodations_data.append(url_data)
    
    return accomodation_data
# Out:
#   File "<ipython-input-5-a9e0b98d2c17>", line 12
#     Iterate over a defined range and scrape the links
#             ^
# SyntaxError: invalid syntax

# %%
import time
def scrape_accommodation_data(driver, accommodation_url):
    '''Visits an accommodation page and extracts the data.'''
 
    if driver == None:
        driver = prepare_driver(accommodation_url)
 
    driver.get(accommodation_url)
    time.sleep(12)
 
    accommodation_fields = dict()
 
    # Get the accommodation name
    accommodation_fields['name'] = driver.find_element_by_id('hp_hotel_name')\
        .text.strip('Hotel')
 
    # Get the accommodation score
    accommodation_fields['score'] = driver.find_element_by_class_name('bui-review-score--end').find_element_by_class_name('bui-review-score__badge').text
    
    #Get hotel rating
    accomodation_fields['rating'] = driver.find_element_by_class_name('bui-rating bui-rating--smaller').text

    
    return accommodation_fields
    print(accommodation_fields)
    
scrape_accommodation_data(driver,'https://www.booking.com/hotel/sg/peninsula-excelsior.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4AtP21YMGwAIB0gIkNDYzN2MzNzgtMzFiMi00ODg3LTgxNmItOTI3NzZiYzMxOTBh2AIF4AIB&sid=5c9d81d37133b7e9abf7fe2ebb7a4196&dest_id=-73635&dest_type=city&group_adults=2&group_children=0&hapos=1&hpos=1&no_rooms=1&sr_order=distance_from_search&srepoch=1618312200&srpvid=9bb14e8316c500f3&ucfs=1&from=searchresults;highlight_room=#hotelTmpl')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-15-2e540bcd9c50> in <module>
#      34     print(accommodation_fields)
#      35
# ---> 36 scrape_accommodation_data(driver,'https://www.booking.com/hotel/sg/peninsula-excelsior.html?aid=304142&label=gen173nr-1FCAEoggI46AdIM1gEaGyIAQGYATG4ARfIAQzYAQHoAQH4AQKIAgGoAgO4AtP21YMGwAIB0gIkNDYzN2MzNzgtMzFiMi00ODg3LTgxNmItOTI3NzZiYzMxOTBh2AIF4AIB&sid=5c9d81d37133b7e9abf7fe2ebb7a4196&dest_id=-73635&dest_type=city&group_adults=2&group_children=0&hapos=1&hpos=1&no_rooms=1&sr_order=distance_from_search&srepoch=1618312200&srpvid=9bb14e8316c500f3&ucfs=1&from=searchresults;highlight_room=#hotelTmpl')
#
# <ipython-input-15-2e540bcd9c50> in scrape_accommodation_data(driver, accommodation_url)
#      19
#      20     #Get hotel rating
# ---> 21     accomodation_fields['rating'] = driver.find_element_by_class_name('bui-rating bui-rating--smaller').text
#      22 #     # Get the accommodation location
#      23 #     accommodation_fields['location'] = driver.find_element_by_id('showMap2')\
#
# c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\ritul\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".bui-rating bui-rating--smaller"}
#   (Session info: chrome=89.0.4389.114)

# %%
def More_review_press(driver, search_argument):

    # We look for the search button and click it
    button = driver.find_element_by_class_name('bui-button bui-button--secondary')
    button.click()
    #wait = WebDriverWait(driver, timeout=10).until(EC.presence_of_all_elements_located((By.CLASS_NAME, 'sr-hotel__title')))
